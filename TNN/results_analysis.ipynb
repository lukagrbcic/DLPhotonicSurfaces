# %%
import numpy as np

# %%
## for inconel task: training from scratch an inverse DNN with a
## forward DNN trained from SCRATCH on inconel
train_losses = [0.01614, 0.01726, 0.01611, 0.01772, 0.01593, 0.01585, 0.01623, 0.01593, 0.02348, 0.01730]
val_losses = [0.01602, 0.01831, 0.01653, 0.01763, 0.01509, 0.01570, 0.01532, 0.01550, 0.02371, 0.01969]
test_losses = [0.01253, 0.01458, 0.01463, 0.01500, 0.01215, 0.01251, 0.01253, 0.01301, 0.01918, 0.01566]

### For inconel task: training from scratch an inverse DNN with a 
### forward DNN (trained on inconel task) that was hot started on stainless steel
train_losses = [0.01958, 0.02049, 0.02130, 0.02136, 0.02121, 0.01950, 0.01973, 0.02153, 0.02090, 0.02054]
val_losses = [0.01947, 0.02072, 0.02043, 0.02062, 0.02066, 0.01913, 0.01872, 0.02057, 0.02127, 0.02005]
test_losses = [0.01611, 0.01761, 0.01740, 0.01676, 0.01712, 0.01571, 0.01543, 0.01690, 0.01717, 0.01612]

# ### for stainless steel task: training from scratch an inverse DNN with a
# ### forward DNN trained from SCRATCH on stainless steel
train_losses = [0.02693, 0.02605, 0.02579, 0.02661, 0.02524, 0.02590, 0.02538, 0.02572, 0.02581, 0.02582]
val_losses = [0.02527, 0.02450, 0.02587, 0.02543, 0.02465, 0.02492, 0.02393, 0.02457, 0.02475, 0.02518]
test_losses = [0.02214, 0.02164, 0.02268, 0.02256, 0.02214, 0.02219, 0.02105, 0.02153, 0.02186, 0.02259]

# ### For inconel task: training from scratch an inverse DNN with a 
# ### forward DNN (trained on inconel task) that was hot started on stainless steel
train_losses = [0.02775, 0.02804, 0.02630, 0.02565, 0.02639, 0.02677, 0.02562, 0.02809, 0.02935, 0.02796]
val_losses = [0.02637, 0.02724, 0.02569, 0.02490, 0.02532, 0.02559, 0.02442, 0.02692, 0.02944, 0.02718]
test_losses = [0.02341, 0.02425, 0.02143, 0.02027, 0.02103, 0.02113, 0.01931, 0.02117, 0.02438, 0.02148]

# %%
# ### for inconel task
# ### forward DNN starting from scratch
# ### inverse DNN hot started on SS
train_losses = [0.02441, 0.05220, 0.02364, 0.01589, 0.01745, 0.05638, 0.05557, 0.05696, 0.05192, 0.01690]
val_losses = [0.02452, 0.05142, 0.02267, 0.01533, 0.01690, 0.05513, 0.05505,  0.05610, 0.05072, 0.01806]
test_losses = [0.02141, 0.04616, 0.02023, 0.01260, 0.01366, 0.05153, 0.05166, 0.05241, 0.04552, 0.01444]

# # ### for inconel task
# # ### forward DNN hot started on SS
# # ### inverse DNN hot started on SS
train_losses = [0.05235, 0.04663, 0.04648, 0.01590, 0.01738, 0.04640, 0.02141, 0.04657, 0.02334, 0.01772]
val_losses = [0.05155,  0.04604, 0.04600, 0.01509, 0.01855, 0.04582, 0.02048,  0.04615, 0.02248, 0.01779]
test_losses = [0.04801, 0.04190, 0.04145, 0.01243, 0.01401, 0.04178, 0.01692, 0.04218, 0.01873, 0.01374]

# # ### for ss task
# # ### forward DNN starting from scratch
# # ### inverse DNN hot started on inconel
train_losses = [0.02563, 0.02865, 0.02514, 0.02564, 0.02554, 0.02473, 0.02602, 0.0245, 0.02542, 0.02599]
val_losses = [0.02434, 0.02734, 0.02388, 0.02454, 0.02412, 0.02365, 0.02477, 0.02339, 0.02412, 0.02511]
test_losses = [0.02113, 0.02293, 0.02061, 0.02143, 0.02097, 0.02040, 0.02133, 0.02051, 0.02074, 0.02167]

# # ### for ss task
# # ### forward DNN hot started on inconel
# # ### inverse DNN hot started on inconel
train_losses = [0.02051, 0.02533, 0.02517, 0.02134, 0.02514, 0.02528, 0.02529, 0.02614, 0.01956, 0.01756]
val_losses = [0.02018, 0.02428, 0.02426, 0.02091, 0.02413, 0.02437, 0.02424, 0.02528, 0.01943, 0.01731]
test_losses = [0.01777, 0.01955, 0.01933, 0.01798, 0.01924, 0.01921, 0.01946, 0.02050, 0.01716, 0.01483]
