# %%
import torch
import torch.nn as nn

# %%
from dnn import forwardMLP

input_size = 3
output_size = 822

model = forwardMLP(input_size=input_size, output_size=output_size)

transfer_model_path = '/home/vpatro/DLPhotonicSurfaces/TNN/forwardDNN/stainless_steel_forward_DNN.pth'

transfer_model = forwardMLP(input_size=input_size, output_size=output_size)
transfer_model.load_state_dict(torch.load(transfer_model_path))

print(type(model.state_dict().values()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 13
#      10 transfer_model = forwardMLP(input_size=input_size, output_size=output_size)
#      11 transfer_model.load_state_dict(torch.load(transfer_model_path))
# ---> 13 print(type(model.state_dict().values()[0]))
#
# TypeError: 'odict_values' object is not subscriptable
