# %%
import pandas as pd
import numpy as np

from scripts.generate_results_table import make_results_df

# %%
dataset = 'inconel'
hot_start_dataset = 'stainless_steel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_transferred = 1
num_forward_layers_transferred = 1

df = make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_transferred, num_forward_layers_transferred)
df
# Out:
# ['../results/inc_ss/standard_loss/standard_inconel_dataset_forwardDNN_from_scratch_inverseDNN_from_scratch.json', '../results/inc_ss/standard_loss/standard_inconel_dataset_forwardDNN_1_layers_stainless_steel_hot_start_inverseDNN_from_scratch.json', '../results/inc_ss/standard_loss/1_layers_transferred/transfer_learning_inconel_dataset_forwardDNN_from_scratch_inverseDNN_hot_start_stainless_steel.json', '../results/inc_ss/standard_loss/1_layers_transferred/transfer_learning_inconel_dataset_forwardDNN_1_layers_stainless_steel_hot_start_inverseDNN_hot_start_stainless_steel.json']
#                    Forward DNN      Inverse DNN             Train RMSE  \
# Config
# Forward Model     from_scratch              n/a  0.02709 (+/- 0.00000)
# Forward Model  stainless_steel              n/a  0.02697 (+/- 0.00000)
# Standard          from_scratch     from_scratch  0.01637 (+/- 0.00149)
# Standard       stainless_steel     from_scratch  0.02118 (+/- 0.00144)
# ...

# %%
dataset = 'stainless_steel'
hot_start_dataset = 'inconel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_transferred = 1
num_forward_layers_transferred = 1


df = make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_transferred, num_forward_layers_transferred)
df
# Out:
# ['../results/inc_ss/standard_loss/standard_stainless_steel_dataset_forwardDNN_from_scratch_inverseDNN_from_scratch.json', '../results/inc_ss/standard_loss/standard_stainless_steel_dataset_forwardDNN_1_layers_inconel_hot_start_inverseDNN_from_scratch.json', '../results/inc_ss/standard_loss/1_layers_transferred/transfer_learning_stainless_steel_dataset_forwardDNN_from_scratch_inverseDNN_hot_start_inconel.json', '../results/inc_ss/standard_loss/1_layers_transferred/transfer_learning_stainless_steel_dataset_forwardDNN_1_layers_inconel_hot_start_inverseDNN_hot_start_inconel.json']
#                 Forward DNN   Inverse DNN             Train RMSE  \
# Config
# Forward Model  from_scratch           n/a  0.03525 (+/- 0.00000)
# Forward Model       inconel           n/a  0.03316 (+/- 0.00000)
# Standard       from_scratch  from_scratch  0.02602 (+/- 0.00041)
# Standard            inconel  from_scratch  0.02695 (+/- 0.00137)
# TL - 1         from_scratch       inconel  0.02490 (+/- 0.00039)
# ...

# %%
dataset = 'inconel'
hot_start_dataset = 'stainless_steel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_transferred = 2
num_forward_layers_transferred = 2

df = make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_transferred, num_forward_layers_transferred)
df
# Out:
# ['../results/inc_ss/standard_loss/standard_inconel_dataset_forwardDNN_from_scratch_inverseDNN_from_scratch.json', '../results/inc_ss/standard_loss/standard_inconel_dataset_forwardDNN_2_layers_stainless_steel_hot_start_inverseDNN_from_scratch.json', '../results/inc_ss/standard_loss/2_layers_transferred/transfer_learning_inconel_dataset_forwardDNN_from_scratch_inverseDNN_hot_start_stainless_steel.json', '../results/inc_ss/standard_loss/2_layers_transferred/transfer_learning_inconel_dataset_forwardDNN_2_layers_stainless_steel_hot_start_inverseDNN_hot_start_stainless_steel.json']
#                    Forward DNN      Inverse DNN             Train RMSE  \
# Config
# Forward Model     from_scratch              n/a  0.02709 (+/- 0.00000)
# Forward Model  stainless_steel              n/a  0.03004 (+/- 0.00000)
# Standard          from_scratch     from_scratch  0.01637 (+/- 0.00149)
# Standard       stainless_steel     from_scratch  0.02209 (+/- 0.00804)
# ...

# %%
dataset = 'stainless_steel'
hot_start_dataset = 'inconel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_transferred = 2
num_forward_layers_transferred = 2


df = make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_transferred, num_forward_layers_transferred)
df
# Out:
# ['../results/inc_ss/standard_loss/standard_stainless_steel_dataset_forwardDNN_from_scratch_inverseDNN_from_scratch.json', '../results/inc_ss/standard_loss/standard_stainless_steel_dataset_forwardDNN_2_layers_inconel_hot_start_inverseDNN_from_scratch.json', '../results/inc_ss/standard_loss/2_layers_transferred/transfer_learning_stainless_steel_dataset_forwardDNN_from_scratch_inverseDNN_hot_start_inconel.json', '../results/inc_ss/standard_loss/2_layers_transferred/transfer_learning_stainless_steel_dataset_forwardDNN_2_layers_inconel_hot_start_inverseDNN_hot_start_inconel.json']
#                 Forward DNN   Inverse DNN             Train RMSE  \
# Config
# Forward Model  from_scratch           n/a  0.03525 (+/- 0.00000)
# Forward Model       inconel           n/a  0.03899 (+/- 0.00000)
# Standard       from_scratch  from_scratch  0.02602 (+/- 0.00041)
# Standard            inconel  from_scratch  0.02612 (+/- 0.00271)
# TL - 1         from_scratch       inconel  0.02521 (+/- 0.00101)
# ...
