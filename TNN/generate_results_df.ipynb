# %%
import pandas as pd
import numpy as np

from generate_results import make_results_df

# %%
dataset = 'inconel'
transfer_dataset = 'stainless_steel'
results_dir = 'results/inc_ss/standard_loss'

df = make_results_df(dataset, transfer_dataset, results_dir)
df
# Out:
#          Config      Forward DNN      Inverse DNN             Train RMSE  \
# 0        No TNN          inconel              n/a  0.03099 (+/- 0.00000)
# 1  TNN Standard          inconel     from scratch  0.01444 (+/- 0.00075)
# 2        TL - 1          inconel  stainless_steel  0.01369 (+/- 0.00018)
# 3        TL - 2  stainless_steel     from scratch  0.03443 (+/- 0.00034)
# 4        TL - 3  stainless_steel  stainless_steel  0.06852 (+/- 0.00013)
#
#                 Val RMSE              Test RMSE           Epochs
# 0  0.03263 (+/- 0.00000)  0.02565 (+/- 0.00000)    0.0 (+/- 0.0)
# 1  0.01489 (+/- 0.00053)  0.01139 (+/- 0.00056)  41.0 (+/- 11.0)
# 2  0.01323 (+/- 0.00016)  0.01047 (+/- 0.00025)   31.5 (+/- 4.5)
# 3  0.03290 (+/- 0.00035)  0.05541 (+/- 0.00164)   27.0 (+/- 7.0)
# 4  0.06703 (+/- 0.00025)  0.04799 (+/- 0.00006)   12.0 (+/- 4.0)

# %%
dataset = 'stainless_steel'
transfer_dataset = 'inconel'
results_dir = 'results/inc_ss/standard_loss'

df = make_results_df(dataset, transfer_dataset, results_dir)
df
