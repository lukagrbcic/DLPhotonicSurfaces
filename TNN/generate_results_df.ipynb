# %%
import pandas as pd
import numpy as np

from generate_results import make_results_df

# %%
dataset = 'inconel'
transfer_dataset = 'stainless_steel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_frozen = 1

df = make_results_df(dataset, transfer_dataset, results_dir, num_inverse_layers_frozen)
df
# Out:
#                    Forward DNN      Inverse DNN             Train RMSE  \
# Config
# Forward Model          inconel              n/a  0.03099 (+/- 0.00000)
# TNN Standard           inconel     from scratch  0.01338 (+/- 0.00276)
# TL - 1                 inconel  stainless_steel  0.01217 (+/- 0.00040)
# TL - 2         stainless_steel     from scratch  0.03288 (+/- 0.00079)
# TL - 3         stainless_steel  stainless_steel  0.06826 (+/- 0.00004)
#
#                             Val RMSE              Test RMSE  \
# Config
# Forward Model  0.03263 (+/- 0.00000)  0.02565 (+/- 0.00000)
# TNN Standard   0.01342 (+/- 0.00275)  0.01002 (+/- 0.00239)
# TL - 1         0.01169 (+/- 0.00048)  0.00910 (+/- 0.00039)
# TL - 2         0.03150 (+/- 0.00097)  0.04956 (+/- 0.00210)
# TL - 3         0.06666 (+/- 0.00028)  0.04715 (+/- 0.00045)
#
#                                       Epochs
# Config
# Forward Model                  0.0 (+/- 0.0)
# TNN Standard    13.2 (+/- 8.405950273467004)
# ...

# %%
dataset = 'stainless_steel'
transfer_dataset = 'inconel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_frozen = 1

df = make_results_df(dataset, transfer_dataset, results_dir, num_inverse_layers_frozen)
df
# Out:
#                    Forward DNN   Inverse DNN             Train RMSE  \
# Config
# Forward Model  stainless_steel           n/a  0.03392 (+/- 0.00000)
# TNN Standard   stainless_steel  from scratch  0.02497 (+/- 0.00100)
# TL - 1         stainless_steel       inconel  0.02000 (+/- 0.00159)
# TL - 2                 inconel  from scratch  0.02374 (+/- 0.00081)
# TL - 3                 inconel       inconel  0.02332 (+/- 0.00031)
#
#                             Val RMSE              Test RMSE  \
# Config
# Forward Model  0.03240 (+/- 0.00000)  0.02726 (+/- 0.00000)
# TNN Standard   0.02343 (+/- 0.00103)  0.01962 (+/- 0.00120)
# TL - 1         0.01935 (+/- 0.00177)  0.01661 (+/- 0.00150)
# TL - 2         0.02287 (+/- 0.00094)  0.09556 (+/- 0.00625)
# TL - 3         0.02258 (+/- 0.00040)  0.10956 (+/- 0.00295)
#
#                                        Epochs
# Config
# Forward Model                   0.0 (+/- 0.0)
# TNN Standard     14.5 (+/- 7.419568720619818)
# ...

# %%
dataset = 'inconel'
transfer_dataset = 'stainless_steel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_frozen = 2

df = make_results_df(dataset, transfer_dataset, results_dir, num_inverse_layers_frozen)
df
# Out:
#                    Forward DNN      Inverse DNN             Train RMSE  \
# Config
# Forward Model          inconel              n/a  0.03099 (+/- 0.00000)
# TNN Standard           inconel     from scratch  0.01338 (+/- 0.00276)
# TL - 1                 inconel  stainless_steel  0.01285 (+/- 0.00030)
# TL - 2         stainless_steel     from scratch  0.03288 (+/- 0.00079)
# TL - 3         stainless_steel  stainless_steel  0.06834 (+/- 0.00004)
#
#                             Val RMSE              Test RMSE  \
# Config
# Forward Model  0.03263 (+/- 0.00000)  0.02565 (+/- 0.00000)
# TNN Standard   0.01342 (+/- 0.00275)  0.01002 (+/- 0.00239)
# TL - 1         0.01246 (+/- 0.00040)  0.00963 (+/- 0.00027)
# TL - 2         0.03150 (+/- 0.00097)  0.04956 (+/- 0.00210)
# TL - 3         0.06669 (+/- 0.00030)  0.04654 (+/- 0.00025)
#
#                                      Epochs
# Config
# Forward Model                 0.0 (+/- 0.0)
# TNN Standard   13.2 (+/- 8.405950273467004)
# ...

# %%
dataset = 'stainless_steel'
transfer_dataset = 'inconel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_frozen = 2

df = make_results_df(dataset, transfer_dataset, results_dir, num_inverse_layers_frozen)
df
# Out:
#                    Forward DNN   Inverse DNN             Train RMSE  \
# Config
# Forward Model  stainless_steel           n/a  0.03392 (+/- 0.00000)
# TNN Standard   stainless_steel  from scratch  0.02497 (+/- 0.00100)
# TL - 1         stainless_steel       inconel  0.01937 (+/- 0.00083)
# TL - 2                 inconel  from scratch  0.02374 (+/- 0.00081)
# TL - 3                 inconel       inconel  0.02455 (+/- 0.00022)
#
#                             Val RMSE              Test RMSE  \
# Config
# Forward Model  0.03240 (+/- 0.00000)  0.02726 (+/- 0.00000)
# TNN Standard   0.02343 (+/- 0.00103)  0.01962 (+/- 0.00120)
# TL - 1         0.01860 (+/- 0.00095)  0.01598 (+/- 0.00081)
# TL - 2         0.02287 (+/- 0.00094)  0.09556 (+/- 0.00625)
# TL - 3         0.02375 (+/- 0.00028)  0.10973 (+/- 0.00260)
#
#                                        Epochs
# Config
# Forward Model                   0.0 (+/- 0.0)
# TNN Standard     14.5 (+/- 7.419568720619818)
# ...

# %%
dataset = 'inconel'
transfer_dataset = 'stainless_steel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_frozen = 3

df = make_results_df(dataset, transfer_dataset, results_dir, num_inverse_layers_frozen)
df
# Out:
#                    Forward DNN      Inverse DNN             Train RMSE  \
# Config
# Forward Model          inconel              n/a  0.03099 (+/- 0.00000)
# TNN Standard           inconel     from scratch  0.01338 (+/- 0.00276)
# TL - 1                 inconel  stainless_steel  0.01786 (+/- 0.00034)
# TL - 2         stainless_steel     from scratch  0.03288 (+/- 0.00079)
# TL - 3         stainless_steel  stainless_steel  0.06846 (+/- 0.00003)
#
#                             Val RMSE              Test RMSE  \
# Config
# Forward Model  0.03263 (+/- 0.00000)  0.02565 (+/- 0.00000)
# TNN Standard   0.01342 (+/- 0.00275)  0.01002 (+/- 0.00239)
# TL - 1         0.01780 (+/- 0.00040)  0.01443 (+/- 0.00030)
# TL - 2         0.03150 (+/- 0.00097)  0.04956 (+/- 0.00210)
# TL - 3         0.06678 (+/- 0.00029)  0.04612 (+/- 0.00018)
#
#                                        Epochs
# Config
# Forward Model                   0.0 (+/- 0.0)
# TNN Standard     13.2 (+/- 8.405950273467004)
# ...

# %%
dataset = 'stainless_steel'
transfer_dataset = 'inconel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_frozen = 3

df = make_results_df(dataset, transfer_dataset, results_dir, num_inverse_layers_frozen)
df
# Out:
#                    Forward DNN   Inverse DNN             Train RMSE  \
# Config
# Forward Model  stainless_steel           n/a  0.03392 (+/- 0.00000)
# TNN Standard   stainless_steel  from scratch  0.02497 (+/- 0.00100)
# TL - 1         stainless_steel       inconel  0.02448 (+/- 0.00033)
# TL - 2                 inconel  from scratch  0.02374 (+/- 0.00081)
# TL - 3                 inconel       inconel  0.02591 (+/- 0.00005)
#
#                             Val RMSE              Test RMSE  \
# Config
# Forward Model  0.03240 (+/- 0.00000)  0.02726 (+/- 0.00000)
# TNN Standard   0.02343 (+/- 0.00103)  0.01962 (+/- 0.00120)
# TL - 1         0.02339 (+/- 0.00042)  0.02034 (+/- 0.00028)
# TL - 2         0.02287 (+/- 0.00094)  0.09556 (+/- 0.00625)
# TL - 3         0.02512 (+/- 0.00008)  0.10307 (+/- 0.00105)
#
#                                        Epochs
# Config
# Forward Model                   0.0 (+/- 0.0)
# TNN Standard     14.5 (+/- 7.419568720619818)
# ...
