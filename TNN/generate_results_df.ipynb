# %%
import pandas as pd
import numpy as np

from generate_results import make_results_df

# %%
dataset = 'inconel'
hot_start_dataset = 'stainless_steel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_transferred = 1

df = make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_transferred)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 results_dir = 'results/inc_ss/standard_loss'
#       4 num_inverse_layers_transferred = 1
# ----> 6 df = make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_transferred)
#       7 df
#
# File ~/DLPhotonicSurfaces/TNN/generate_results.py:41, in make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_to_transfer)
#      37 paths = [standard_fwd_from_scratch_path, standard_fwd_hot_start, tl_1_path, tl_2_path]
#      39 for path in paths:
# ---> 41     with open(path, 'r') as f:
#      42         data = json.load(f)
#      44     train_losses.append(data['mean train loss'])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/inc_ss/standard_loss/1_layers_transferred/standard_inconel_dataset_forwardDNN_from_scratch_inverseDNN_from_scratch.json'

# %%
dataset = 'stainless_steel'
hot_start_dataset = 'inconel'
results_dir = 'results/inc_ss/standard_loss'
num_inverse_layers_transferred = 1

df = make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_transferred)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 results_dir = 'results/inc_ss/standard_loss'
#       4 num_inverse_layers_transferred = 1
# ----> 6 df = make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_transferred)
#       7 df
#
# File ~/DLPhotonicSurfaces/TNN/generate_results.py:41, in make_results_df(dataset, hot_start_dataset, results_dir, num_inverse_layers_to_transfer)
#      37 paths = [standard_fwd_from_scratch_path, standard_fwd_hot_start, tl_1_path, tl_2_path]
#      39 for path in paths:
# ---> 41     with open(path, 'r') as f:
#      42         data = json.load(f)
#      44     train_losses.append(data['mean train loss'])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/inc_ss/standard_loss/1_layers_transferred/standard_stainless_steel_dataset_forwardDNN_from_scratch_inverseDNN_from_scratch.json'
